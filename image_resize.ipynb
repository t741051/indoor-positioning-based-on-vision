# %%
target_image_size = (75, 75)

# %%
import os
from PIL import Image

def resize_images(folder_path):
    # 遍歷資料夾中的所有檔案和子資料夾
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # 判斷是否為圖片檔案
            if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith(".png"):
                # 讀取圖片
                img_path = os.path.join(root, file)
                img = Image.open(img_path)

                # 將圖片 resize 成 target_image_size
                img = img.resize(target_image_size)

                # 儲存 resized 圖片
                resized_img_path = os.path.join(root, file)
                img.save(resized_img_path)

                print(f"{img_path} resized and saved as {resized_img_path}")

# 指定資料夾路徑
folder_path = "./Dataset/train"

# 呼叫 resize_images 函數
resize_images(folder_path)
# Out:
# ./Dataset/train\1-1\EE_7_1_1_0.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_0.jpg
# ./Dataset/train\1-1\EE_7_1_1_1.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_1.jpg
# ./Dataset/train\1-1\EE_7_1_1_10.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_10.jpg
# ./Dataset/train\1-1\EE_7_1_1_11.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_11.jpg
# ./Dataset/train\1-1\EE_7_1_1_12.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_12.jpg
# ./Dataset/train\1-1\EE_7_1_1_13.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_13.jpg
# ./Dataset/train\1-1\EE_7_1_1_14.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_14.jpg
# ./Dataset/train\1-1\EE_7_1_1_2.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_2.jpg
# ./Dataset/train\1-1\EE_7_1_1_3.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_3.jpg
# ./Dataset/train\1-1\EE_7_1_1_4.jpg resized and saved as ./Dataset/train\1-1\EE_7_1_1_4.jpg
# ...

# %%
import os
from PIL import Image

def resize_images(folder_path):
    # 遍歷資料夾中的所有檔案和子資料夾
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # 判斷是否為圖片檔案
            if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith(".png"):
                # 讀取圖片
                img_path = os.path.join(root, file)
                img = Image.open(img_path)

                # 將圖片 resize 成 target_image_size
                img = img.resize(target_image_size)

                # 儲存 resized 圖片
                resized_img_path = os.path.join(root, file)
                img.save(resized_img_path)

                print(f"{img_path} resized and saved as {resized_img_path}")

# 指定資料夾路徑
folder_path = "./Dataset/test"

# 呼叫 resize_images 函數
resize_images(folder_path)
# Out:
# ./Dataset/test\1-1\EE_7_1_1_10.jpg resized and saved as ./Dataset/test\1-1\EE_7_1_1_10.jpg
# ./Dataset/test\1-1\EE_7_1_1_11.jpg resized and saved as ./Dataset/test\1-1\EE_7_1_1_11.jpg
# ./Dataset/test\1-1\EE_7_1_1_12.jpg resized and saved as ./Dataset/test\1-1\EE_7_1_1_12.jpg
# ./Dataset/test\1-1\EE_7_1_1_13.jpg resized and saved as ./Dataset/test\1-1\EE_7_1_1_13.jpg
# ./Dataset/test\1-1\EE_7_1_1_14.jpg resized and saved as ./Dataset/test\1-1\EE_7_1_1_14.jpg
# ./Dataset/test\1-1\EE_7_1_1_8.jpg resized and saved as ./Dataset/test\1-1\EE_7_1_1_8.jpg
# ./Dataset/test\1-1\EE_7_1_1_9.jpg resized and saved as ./Dataset/test\1-1\EE_7_1_1_9.jpg
# ./Dataset/test\1-1\IMAG0177.jpg resized and saved as ./Dataset/test\1-1\IMAG0177.jpg
# ./Dataset/test\1-1\IMAG0178.jpg resized and saved as ./Dataset/test\1-1\IMAG0178.jpg
# ./Dataset/test\1-1\IMAG0179.jpg resized and saved as ./Dataset/test\1-1\IMAG0179.jpg
# ./Dataset/test\1-1\IMAG0180.jpg resized and saved as ./Dataset/test\1-1\IMAG0180.jpg
# ...

# %%
import os
from PIL import Image

def resize_images(folder_path):
    # 遍歷資料夾中的所有檔案和子資料夾
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # 判斷是否為圖片檔案
            if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith(".png"):
                # 讀取圖片
                img_path = os.path.join(root, file)
                img = Image.open(img_path)

                # 將圖片 resize 成 target_image_size
                img = img.resize(target_image_size)

                # 儲存 resized 圖片
                resized_img_path = os.path.join(root, file)
                img.save(resized_img_path)

                print(f"{img_path} resized and saved as {resized_img_path}")

# 指定資料夾路徑
folder_path = "./Dataset/val"

# 呼叫 resize_images 函數
resize_images(folder_path)
# Out:
# ./Dataset/val\1-1\EE_7_1_1_0.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_0.jpg
# ./Dataset/val\1-1\EE_7_1_1_1.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_1.jpg
# ./Dataset/val\1-1\EE_7_1_1_2.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_2.jpg
# ./Dataset/val\1-1\EE_7_1_1_3.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_3.jpg
# ./Dataset/val\1-1\EE_7_1_1_4.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_4.jpg
# ./Dataset/val\1-1\EE_7_1_1_5.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_5.jpg
# ./Dataset/val\1-1\EE_7_1_1_6.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_6.jpg
# ./Dataset/val\1-1\EE_7_1_1_7.jpg resized and saved as ./Dataset/val\1-1\EE_7_1_1_7.jpg
# ./Dataset/val\1-1\IMG_20230509_200219.jpg resized and saved as ./Dataset/val\1-1\IMG_20230509_200219.jpg
# ./Dataset/val\1-1\IMG_20230509_200220.jpg resized and saved as ./Dataset/val\1-1\IMG_20230509_200220.jpg
# ...
